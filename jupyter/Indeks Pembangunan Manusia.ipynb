# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ipm = pd.read_csv('indeks_pembangunan_manusia.csv')

# %%
df_ipm
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 373  374             32    JAWA BARAT                 3275
# 374  375             32    JAWA BARAT                 3276
# 375  376             32    JAWA BARAT                 3277
# 376  377             32    JAWA BARAT                 3278
# 377  378             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# 0       KABUPATEN BOGOR                       64.35   POIN   2010
# 1    KABUPATEN SUKABUMI                       60.69   POIN   2010
# ...

# %%
df_ipm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          378 non-null    int64
#  1   kode_provinsi               378 non-null    int64
#  2   nama_provinsi               378 non-null    object
#  3   kode_kabupaten_kota         378 non-null    int64
#  4   nama_kabupaten_kota         378 non-null    object
#  5   indeks_pembangunan_manusia  378 non-null    float64
#  6   satuan                      378 non-null    object
#  7   tahun                       378 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 23.8+ KB

# %%
df_ipm_2010 = df_ipm[df_ipm['tahun'] == 2010]

# %%
df_ipm_2010
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                 3201
# 1    2             32    JAWA BARAT                 3202
# 2    3             32    JAWA BARAT                 3203
# 3    4             32    JAWA BARAT                 3204
# 4    5             32    JAWA BARAT                 3205
# 5    6             32    JAWA BARAT                 3206
# 6    7             32    JAWA BARAT                 3207
# 7    8             32    JAWA BARAT                 3208
# 8    9             32    JAWA BARAT                 3209
# 9   10             32    JAWA BARAT                 3210
# 10  11             32    JAWA BARAT                 3211
# 11  12             32    JAWA BARAT                 3212
# 12  13             32    JAWA BARAT                 3213
# 13  14             32    JAWA BARAT                 3214
# 14  15             32    JAWA BARAT                 3215
# ...

# %%
df_jabar = df_ipm.groupby('nama_kabupaten_kota')
df_jabar
df_jabar_ipm = df_jabar.agg({'indeks_pembangunan_manusia':'mean'})
df_jabar_ipm
# Out:
#                          indeks_pembangunan_manusia
# nama_kabupaten_kota
# KABUPATEN BANDUNG                         70.626429
# KABUPATEN BANDUNG BARAT                   65.963571
# KABUPATEN BEKASI                          72.060714
# KABUPATEN BOGOR                           68.459286
# KABUPATEN CIAMIS                          68.680714
# KABUPATEN CIANJUR                         63.175000
# KABUPATEN CIREBON                         67.047143
# KABUPATEN GARUT                           64.058571
# KABUPATEN INDRAMAYU                       65.123571
# KABUPATEN KARAWANG                        68.636429
# KABUPATEN KUNINGAN                        67.710714
# KABUPATEN MAJALENGKA                      65.652143
# KABUPATEN PANGANDARAN                     52.745000
# KABUPATEN PURWAKARTA                      68.780714
# KABUPATEN SUBANG                          67.209286
# KABUPATEN SUKABUMI                        64.990000
# KABUPATEN SUMEDANG                        69.811429
# ...

# %%
df_jabar_ipm['ranking'] = df_jabar_ipm['indeks_pembangunan_manusia'].rank(ascending=False)
df_jabar_ipm['ranking_dari_bawah'] = df_jabar_ipm['indeks_pembangunan_manusia'].rank(ascending=True)
df_jabar_ipm = df_jabar_ipm.reset_index()
df_jabar_ipm
# Out:
#         nama_kabupaten_kota  indeks_pembangunan_manusia  ranking  \
# 0         KABUPATEN BANDUNG                   70.626429     10.0
# 1   KABUPATEN BANDUNG BARAT                   65.963571     20.0
# 2          KABUPATEN BEKASI                   72.060714      8.0
# 3           KABUPATEN BOGOR                   68.459286     16.0
# 4          KABUPATEN CIAMIS                   68.680714     14.0
# 5         KABUPATEN CIANJUR                   63.175000     26.0
# 6         KABUPATEN CIREBON                   67.047143     19.0
# 7           KABUPATEN GARUT                   64.058571     24.0
# 8       KABUPATEN INDRAMAYU                   65.123571     22.0
# 9        KABUPATEN KARAWANG                   68.636429     15.0
# 10       KABUPATEN KUNINGAN                   67.710714     17.0
# 11     KABUPATEN MAJALENGKA                   65.652143     21.0
# 12    KABUPATEN PANGANDARAN                   52.745000     27.0
# ...

# %%
df_jabar_ipm['ranking'] = df_jabar_ipm['indeks_pembangunan_manusia'].rank(ascending=False)

# %%
df_ipm_terbawah = df_jabar_ipm[df_jabar_ipm['ranking_dari_bawah']<=5].sort_values(by='ranking',ascending=False)
df_ipm_terbawah
# Out:
#       nama_kabupaten_kota  indeks_pembangunan_manusia  ranking  \
# 12  KABUPATEN PANGANDARAN                   52.745000     27.0
# 5       KABUPATEN CIANJUR                   63.175000     26.0
# 17  KABUPATEN TASIKMALAYA                   63.987857     25.0
# 7         KABUPATEN GARUT                   64.058571     24.0
# 15     KABUPATEN SUKABUMI                   64.990000     23.0
#
#     ranking_dari_bawah
# 12                 1.0
# 5                  2.0
# 17                 3.0
# 7                  4.0
# 15                 5.0

# %%
df_ipm_terbaik = df_jabar_ipm[df_jabar_ipm['ranking']<=5].sort_values(by='ranking_dari_bawah')
df_ipm_terbaik
# Out:
#    nama_kabupaten_kota  indeks_pembangunan_manusia  ranking  \
# 21          KOTA BOGOR                   74.578571      5.0
# 22         KOTA CIMAHI                   76.780000      4.0
# 24          KOTA DEPOK                   79.570000      3.0
# 20         KOTA BEKASI                   80.062857      2.0
# 18        KOTA BANDUNG                   80.232143      1.0
#
#     ranking_dari_bawah
# 21                23.0
# 22                24.0
# 24                25.0
# 20                26.0
# 18                27.0

# %%
df_ipm_terbaik.to_csv('ipm_jabar.csv')

# %%
df_ipm_terbawah.to_csv('ipm_jabar_terbawah.csv')

# %%
plt.barh(df_ipm_terbaik['nama_kabupaten_kota'], df_ipm_terbaik['indeks_pembangunan_manusia'])

# Beri label pada sumbu
plt.xlabel('Indeks Pembangunan Manusia')
plt.ylabel('Nama Kabupaten Kota')

# Beri judul pada plot
plt.title('Bar Plot Indeks Pembangunan Manusia Terbaik di Jabar')

plt.show()

# %%
plt.barh(df_ipm_terbawah['nama_kabupaten_kota'], df_ipm_terbawah['indeks_pembangunan_manusia'])

# Beri label pada sumbu
plt.xlabel('Indeks Pembangunan Manusia')
plt.ylabel('Nama Kabupaten Kota')

# Beri judul pada plot
plt.title('Bar Plot Indeks Pembangunan Manusia Terbawah di Jabar')

plt.show()

# %%
df_depok = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA DEPOK']
df_depok
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 23    24             32    JAWA BARAT                 3276
# 50    51             32    JAWA BARAT                 3276
# 77    78             32    JAWA BARAT                 3276
# 104  105             32    JAWA BARAT                 3276
# 131  132             32    JAWA BARAT                 3276
# 158  159             32    JAWA BARAT                 3276
# 185  186             32    JAWA BARAT                 3276
# 212  213             32    JAWA BARAT                 3276
# 239  240             32    JAWA BARAT                 3276
# 266  267             32    JAWA BARAT                 3276
# 293  294             32    JAWA BARAT                 3276
# 320  321             32    JAWA BARAT                 3276
# 347  348             32    JAWA BARAT                 3276
# 374  375             32    JAWA BARAT                 3276
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
df_bandung = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA BANDUNG']
df_bandung
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 20    21             32    JAWA BARAT                 3273
# 47    48             32    JAWA BARAT                 3273
# 74    75             32    JAWA BARAT                 3273
# 101  102             32    JAWA BARAT                 3273
# 128  129             32    JAWA BARAT                 3273
# 155  156             32    JAWA BARAT                 3273
# 182  183             32    JAWA BARAT                 3273
# 209  210             32    JAWA BARAT                 3273
# 236  237             32    JAWA BARAT                 3273
# 263  264             32    JAWA BARAT                 3273
# 290  291             32    JAWA BARAT                 3273
# 317  318             32    JAWA BARAT                 3273
# 344  345             32    JAWA BARAT                 3273
# 371  372             32    JAWA BARAT                 3273
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
df_bogor = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA BOGOR']
df_bogor
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 18    19             32    JAWA BARAT                 3271
# 45    46             32    JAWA BARAT                 3271
# 72    73             32    JAWA BARAT                 3271
# 99   100             32    JAWA BARAT                 3271
# 126  127             32    JAWA BARAT                 3271
# 153  154             32    JAWA BARAT                 3271
# 180  181             32    JAWA BARAT                 3271
# 207  208             32    JAWA BARAT                 3271
# 234  235             32    JAWA BARAT                 3271
# 261  262             32    JAWA BARAT                 3271
# 288  289             32    JAWA BARAT                 3271
# 315  316             32    JAWA BARAT                 3271
# 342  343             32    JAWA BARAT                 3271
# 369  370             32    JAWA BARAT                 3271
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
df_bekasi = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA BEKASI']
df_bekasi
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 22    23             32    JAWA BARAT                 3275
# 49    50             32    JAWA BARAT                 3275
# 76    77             32    JAWA BARAT                 3275
# 103  104             32    JAWA BARAT                 3275
# 130  131             32    JAWA BARAT                 3275
# 157  158             32    JAWA BARAT                 3275
# 184  185             32    JAWA BARAT                 3275
# 211  212             32    JAWA BARAT                 3275
# 238  239             32    JAWA BARAT                 3275
# 265  266             32    JAWA BARAT                 3275
# 292  293             32    JAWA BARAT                 3275
# 319  320             32    JAWA BARAT                 3275
# 346  347             32    JAWA BARAT                 3275
# 373  374             32    JAWA BARAT                 3275
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
df_kab_bogor = df_ipm[df_ipm['nama_kabupaten_kota']=='KABUPATEN BOGOR']
df_kab_bogor
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 27    28             32    JAWA BARAT                 3201
# 54    55             32    JAWA BARAT                 3201
# 81    82             32    JAWA BARAT                 3201
# 108  109             32    JAWA BARAT                 3201
# 135  136             32    JAWA BARAT                 3201
# 162  163             32    JAWA BARAT                 3201
# 189  190             32    JAWA BARAT                 3201
# 216  217             32    JAWA BARAT                 3201
# 243  244             32    JAWA BARAT                 3201
# 270  271             32    JAWA BARAT                 3201
# 297  298             32    JAWA BARAT                 3201
# 324  325             32    JAWA BARAT                 3201
# 351  352             32    JAWA BARAT                 3201
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
df_kab_bekasi = df_ipm[df_ipm['nama_kabupaten_kota']=='KABUPATEN BEKASI']
df_kab_bekasi
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 15    16             32    JAWA BARAT                 3216
# 42    43             32    JAWA BARAT                 3216
# 69    70             32    JAWA BARAT                 3216
# 96    97             32    JAWA BARAT                 3216
# 123  124             32    JAWA BARAT                 3216
# 150  151             32    JAWA BARAT                 3216
# 177  178             32    JAWA BARAT                 3216
# 204  205             32    JAWA BARAT                 3216
# 231  232             32    JAWA BARAT                 3216
# 258  259             32    JAWA BARAT                 3216
# 285  286             32    JAWA BARAT                 3216
# 312  313             32    JAWA BARAT                 3216
# 339  340             32    JAWA BARAT                 3216
# 366  367             32    JAWA BARAT                 3216
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# ...

# %%
plt.plot(df_depok['tahun'], df_depok['indeks_pembangunan_manusia'])

# Beri label pada sumbu
plt.xlabel('Tahun')
plt.ylabel('Indeks Pembangunan Manusia')

# Beri judul pada plot
plt.title('Indeks Pembangunan Manusia Depok 2010-2023')
# Out:
# Text(0.5, 1.0, 'Indeks Pembangunan Manusia Depok 2010-2023')

# %%
df_depok.to_csv('lineplot_depok.csv')

# %%
pivot_table = df_ipm.pivot_table(values='indeks_pembangunan_manusia', index='nama_kabupaten_kota', columns='tahun', aggfunc='sum')
pivot_table
# Out:
# tahun                     2010   2011   2012   2013   2014   2015   2016  \
# nama_kabupaten_kota
# KABUPATEN BANDUNG        67.28  67.78  68.13  68.58  69.06  70.05  70.69
# KABUPATEN BANDUNG BARAT  61.34  62.36  63.17  63.93  64.27  65.23  65.81
# KABUPATEN BEKASI         67.58  68.66  69.38  70.09  70.51  71.19  71.83
# KABUPATEN BOGOR          64.35  64.78  65.66  66.74  67.36  67.77  68.32
# KABUPATEN CIAMIS         64.64  65.48  66.29  67.20  67.64  68.02  68.45
# KABUPATEN CIANJUR        58.58  59.38  60.28  61.68  62.08  62.42  62.92
# KABUPATEN CIREBON        63.64  64.17  64.48  65.06  65.53  66.07  66.70
# KABUPATEN GARUT          60.23  60.55  61.04  61.67  62.23  63.21  63.64
# KABUPATEN INDRAMAYU      60.86  61.47  62.09  62.98  63.55  64.36  64.78
# KABUPATEN KARAWANG       64.58  65.21  65.97  66.61  67.08  67.66  68.19
# KABUPATEN KUNINGAN       64.40  65.04  65.60  66.16  66.63  67.19  67.51
# KABUPATEN MAJALENGKA     62.30  62.67  63.13  63.71  64.07  64.75  65.25
# ...

# %%
def bodebek(x):
    if x in ['KOTA DEPOK', 'KOTA BOGOR', 'KOTA BEKASI', 'KABUPATEN BOGOR', 'KABUPATEN BEKASI']:
        return 'bodebek'
    else :
        return 'others'

# %%
df_bodebek_ipm = df_ipm.copy()
df_bodebek_ipm['bodebek'] = df_bodebek_ipm['nama_kabupaten_kota'].apply(bodebek)
df_bodebek_ipm
df_bodebek_ipm = df_bodebek_ipm[df_bodebek_ipm['bodebek']=='bodebek']
df_bodebek_ipm
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 15    16             32    JAWA BARAT                 3216
# 18    19             32    JAWA BARAT                 3271
# 22    23             32    JAWA BARAT                 3275
# 23    24             32    JAWA BARAT                 3276
# ..   ...            ...           ...                  ...
# 351  352             32    JAWA BARAT                 3201
# 366  367             32    JAWA BARAT                 3216
# 369  370             32    JAWA BARAT                 3271
# 373  374             32    JAWA BARAT                 3275
# 374  375             32    JAWA BARAT                 3276
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun  bodebek
# 0       KABUPATEN BOGOR                       64.35   POIN   2010  bodebek
# 15     KABUPATEN BEKASI                       67.58   POIN   2010  bodebek
# ...

# %%
kota_depok = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA DEPOK']
kota_bogor = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA BOGOR']
kota_bekasi = df_ipm[df_ipm['nama_kabupaten_kota']=='KOTA BEKASI']
kab_bogor = df_ipm[df_ipm['nama_kabupaten_kota']=='KABUPATEN BOGOR']
kab_bekasi = df_ipm[df_ipm['nama_kabupaten_kota']=='KABUPATEN BEKASI']

# %%
x = df_ipm['tahun'].unique()
y1 = kota_depok['indeks_pembangunan_manusia']
y2 = kota_bogor['indeks_pembangunan_manusia']
y3 = kota_bekasi['indeks_pembangunan_manusia']
y4 = kab_bogor['indeks_pembangunan_manusia']
y5 = kab_bekasi['indeks_pembangunan_manusia']

plt.plot(x, y1, label='Kota Depok', color='blue')
plt.plot(x, y2, label='Kota Bogor', color='green')
plt.plot(x, y3, label='Kota Bekasi', color='black')
plt.plot(x, y4, label='Kabupaten Bogor', color='red')
plt.plot(x, y5, label='Kabupaten Bekasi', color='brown')

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_ipm.to_csv
# Out:
# <bound method NDFrame.to_csv of       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 373  374             32    JAWA BARAT                 3275
# 374  375             32    JAWA BARAT                 3276
# 375  376             32    JAWA BARAT                 3277
# 376  377             32    JAWA BARAT                 3278
# 377  378             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# 0       KABUPATEN BOGOR                       64.35   POIN   2010
# 1    KABUPATEN SUKABUMI                       60.69   POIN   2010
# ...

# %%
df_jabar = df_ipm[df_ipm['tahun']==2023]
df_ipm_2023 = df_jabar[(df_jabar['nama_kabupaten_kota']=='KOTA DEPOK') | (df_jabar['nama_kabupaten_kota']=='KOTA BEKASI') | (df_jabar['nama_kabupaten_kota']=='KOTA BOGOR') | (df_jabar['nama_kabupaten_kota']=='KABUPATEN BEKASI') | (df_jabar['nama_kabupaten_kota']=='KABUPATEN BOGOR')]
df_ipm_2023 = df_ipm_2023.sort_values(by='indeks_pembangunan_manusia')
df_ipm_2023
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 351  352             32    JAWA BARAT                 3201
# 366  367             32    JAWA BARAT                 3216
# 369  370             32    JAWA BARAT                 3271
# 374  375             32    JAWA BARAT                 3276
# 373  374             32    JAWA BARAT                 3275
#
#     nama_kabupaten_kota  indeks_pembangunan_manusia satuan  tahun
# 351     KABUPATEN BOGOR                       71.78   POIN   2023
# 366    KABUPATEN BEKASI                       75.76   POIN   2023
# 369          KOTA BOGOR                       77.85   POIN   2023
# 374          KOTA DEPOK                       82.38   POIN   2023
# 373         KOTA BEKASI                       83.03   POIN   2023

# %%
plt.barh(df_ipm_2023['nama_kabupaten_kota'], df_ipm_2023['indeks_pembangunan_manusia'])
plt.ylabel('Kota/Kabupaten')
plt.xlabel('Indeks Pembangunan Manusia')
plt.title('Indeks Pemabngunan Manusia Bodebek 2023')
plt.show()

# %%
df_ipm_2023.to_csv('ipm_bodebek_2023.csv')

# %%
plt.boxplot([y1,y2,y3,y4,y5], labels=['Kota Depok', 'Kota Bogor', 'Kota Bekasi', 'Kab Bogor', 'Kab Bekasi'], showmeans=True)
plt.show()

# %%
from scipy import stats

stats.f_oneway(y1,y2,y3,y4,y5)
# Out:
# F_onewayResult(statistic=70.86479883497874, pvalue=5.47132434625813e-23)

# %% [markdown]
# karena p-value < 0,05 sebagai tingkat kepercayaan, maka kami menolak H Kesimpulan : setidaknya ada satu kelompok yang memiliki perbedaan angka IPM yang signifikan Kemungkinan penyebabnya : terdapat perbedaan faktor yang mempengaruhi IPM di setiap kota atau kabupaten di Jawa Barat

# %%
df_ipm_terbaik = df_jabar_ipm[df_jabar_ipm['ranking']<=5].sort_values(by='ranking_dari_bawah')
df_ipm_terbaik
# Out:
#    nama_kabupaten_kota  indeks_pembangunan_manusia  ranking  \
# 21          KOTA BOGOR                   74.578571      5.0
# 22         KOTA CIMAHI                   76.780000      4.0
# 24          KOTA DEPOK                   79.570000      3.0
# 20         KOTA BEKASI                   80.062857      2.0
# 18        KOTA BANDUNG                   80.232143      1.0
#
#     ranking_dari_bawah
# 21                23.0
# 22                24.0
# 24                25.0
# 20                26.0
# 18                27.0

# %%
df_ipm_terbaik.to_csv('ipm_jabar.csv')

# %%
df_ipm_terbawah.to_csv('ipm_jabar_terbawah.csv')

# %%
plt.barh(df_ipm_terbaik['nama_kabupaten_kota'], df_ipm_terbaik['indeks_pembangunan_manusia'])

# Beri label pada sumbu
plt.xlabel('Indeks Pembangunan Manusia')
plt.ylabel('Nama Kabupaten Kota')

# Beri judul pada plot
plt.title('Bar Plot Indeks Pembangunan Manusia Terbaik di Jabar')

plt.show()

# %%
import matplotlib.pyplot as plt

# # Data Indeks Pembangunan Manusia
# data = {
#     "Kota": ["Bandung", "Bekasi", "Depok", "Cimahi", "Bogor"],
#     "IPM 2010": [70.23, 68.12, 69.45, 71.02, 72.34],
#     "IPM 2023": [78.54, 76.23, 77.89, 80.12, 81.45]
# }

# Buat barplot
fig, ax = plt.subplots()
ax.barh(df_ipm_terbaik["nama_kabupaten_kota"], df_ipm_terbaik["indeks_pembangunan_manusia"], color=["#3366cc", "#3366cc", "#808080", "#3366cc", "#3366cc"])

# Beri label pada sumbu
plt.xlabel("Kota")
plt.ylabel("Indeks Pembangunan Manusia (IPM)")

plt.show()
